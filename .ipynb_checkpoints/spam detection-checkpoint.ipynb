# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import string
import warnings
warnings.filterwarnings('ignore')
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from collections import defaultdict
from wordcloud import WordCloud
from sklearn.metrics import confusion_matrix,f1_score
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\monika\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
data = pd.read_csv("D:/MachineLearning/spam detection/spam.csv", encoding='ISO 8859-1')

# %%
data.head()
# Out:
#      v1                                                 v2 Unnamed: 2  \
# 0   ham  Go until jurong point, crazy.. Available only ...        NaN
# 1   ham                      Ok lar... Joking wif u oni...        NaN
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3   ham  U dun say so early hor... U c already then say...        NaN
# 4   ham  Nah I don't think he goes to usf, he lives aro...        NaN
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 5 columns):
# v1            5572 non-null object
# v2            5572 non-null object
# Unnamed: 2    50 non-null object
# Unnamed: 3    12 non-null object
# Unnamed: 4    6 non-null object
# dtypes: object(5)
# memory usage: 217.7+ KB

# %%
data.fillna(" ", inplace=True)
data['text_message'] = data['v2'] + data['Unnamed: 2'] + data['Unnamed: 3'] + data['Unnamed: 4']

# %%
data1 = data[['v1', 'text_message']]
data1.dropna(inplace=True)
data['v1'].value_counts()
# Out:
# ham     4825
# spam     747
# Name: v1, dtype: int64

# %% [markdown]
# ### Now we preprocess the data-
#
#   1.remove all extra whitespaces.
#   2.lower case all the letters.
#   3.remove punctuations.
#   4.tokenize eac message.
#   5.remove stopwords like 'the','in' etc that doesn't add meaning to the message.
#   6.stem each word to it's root word e.g go,goes,going,gone becomes go.
#   7.remove single letter words (i,a etc)
#   8.encode ham=0 and spam=1.

# %%
data1['text_message'] = data1['text_message'].str.strip()
data1['text_message'] = data1['text_message'].str.lower()

# %%
#remove punctuation
punc = string.punctuation
table = str.maketrans('','',punc)
data1['text_message']=data1['text_message'].apply(lambda x: x.translate(table))

# %%
data1['word_tokens'] = data1.apply(lambda x: x['text_message'].split(' '), axis=1)

# %%
data1['cleaned_text'] = data1.apply(lambda x: [word for word in x['word_tokens'] if word not in stopwords.words('english')], axis=1)

# %%
# stemming
ps = PorterStemmer()
data1['stemmed']= data1.apply(lambda x: [ps.stem(word) for word in x['cleaned_text']],axis=1)

# %%
# remove single letter words
data1['final_text'] = data1.apply(lambda x: ' '.join([word for word in x['stemmed'] if len(word)>1]),axis=1)

# %%
 # label encoding ham=0 and spam=1
data1.loc[data1['v1']=='ham','v1']=0
data1.loc[data1['v1']=='spam','v1']=1

# %%
# divide the set in training and test
from sklearn.model_selection import train_test_split
X,X_test,y,y_test = train_test_split(data1.loc[:,'text_message':],data1['v1'],test_size=0.2)

# %%
# Now we'll create a vocabulary for the training set with word count
vocab=defaultdict(int) 
for text in X['final_text'].values:
    for element in text.split(' '):
        vocab[element]+=1

# %%
ham_text = ' '.join(X.loc[y==0,'final_text'].values)
ham_wordcloud = WordCloud(background_color='white',max_words=2000).generate(ham_text)
spam_text = ' '.join(X.loc[y==1,'final_text'].values)
spam_wordcloud = WordCloud(background_color='white',max_words=2000).generate(spam_text)
plt.figure(figsize=[20, 30])
plt.subplot(1,2,1)
plt.imshow(spam_wordcloud, interpolation='bilinear')
plt.title("SPAM")
plt.axis('off')
plt.subplot(1,2,2)
plt.imshow(ham_wordcloud, interpolation='bilinear')
plt.title('HAM')
plt.axis("off")
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %%
# We see that call, free text, claim etc are the most used words in spam.
# tokenize the text for further calculations
X['tokenized_final_text']=X['final_text'].str.split(' ')
X_test['tokenized_final_text']=X_test['final_text'].str.split(' ')

# %%
# document frequency(number of docs containing word w) and Inverse document frequency(measures rarity of each word)
df={}
for k in vocab.keys():
    df[k]=np.sum(X['tokenized_final_text'].apply(lambda x: 1 if k in x else 0))
    
# Now we'll calculate the idf score of each word
idf = {k:1+np.log((1+X.shape[0]/(1+v))) for k,v in df.items()}

# %%
# tf * idf
for elem in vocab.keys():
    X[elem]= X['tokenized_final_text'].apply(lambda x: x.count(elem)*idf[elem] if elem in x else 0)
for elem in vocab.keys():
    X_test[elem]= X_test['tokenized_final_text'].apply(lambda x: x.count(elem)*idf[elem] if elem in x else 0)

# %%
y=y.astype('int')
y_test = y_test.astype('int')

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(max_depth=70, random_state=3)
rf.fit(X.iloc[:,6:],y)
confusion_matrix(y,rf.predict(X.iloc[:,6:]))
# Out:
# array([[3841,    0],
#        [  44,  572]], dtype=int64)

# %%
confusion_matrix(y_test,rf.predict(X_test.iloc[:,6:]))
# Out:
# array([[982,   2],
#        [ 33,  98]], dtype=int64)

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lr.fit(X.iloc[:,6:],y)
confusion_matrix(y,lr.predict(X.iloc[:,6:]))
# Out:
# array([[3841,    0],
#        [   0,  616]], dtype=int64)

# %%
confusion_matrix(y_test,lr.predict(X_test.iloc[:,6:]))
# Out:
# array([[984,   0],
#        [ 21, 110]], dtype=int64)

# %%
lr
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
#accuracy and f1 score of random forest
print("RANDOM FOREST ")
print("F1 SCORE", f1_score(y_test,rf.predict(X_test.iloc[:,6:])))
print ("ACCURACY SCORE", rf.score(X_test.iloc[:,6:], y_test))
# Out:
# RANDOM FOREST
# F1 SCORE 0.8484848484848484
# ACCURACY SCORE 0.968609865470852

# %%
#accuracy and f1 score of logistic regression
print("LOGISTIC REGRESSION")
print("F1 SCORE", f1_score(y_test,lr.predict(X_test.iloc[:,6:])))
print("ACCURACY SCORE", lr.score(X_test.iloc[:,6:], y_test))
# Out:
# LOGISTIC REGRESSION
# F1 SCORE 0.9128630705394191
# ACCURACY SCORE 0.9811659192825112

# %% [markdown]
# So in this case logistic regression works better than random forest.
#
# Positive coefficients try to shift the predictions towards spam as the sigmoid will tend to 1 and thus making spam prediction while the negative features contribute to ham. Let's see some of these features.

# %%
ham_20 = np.argsort(lr.coef_)[0][:20]
spam_20 = np.argsort(lr.coef_)[0][:-20]

# %%
features =X.iloc[:,6:].columns
print("_____SPAM FEATURE_____")
for element in spam_20:
    print(features[element])
print("_____Ham FEATURE______")
for element in ham_20:
    print(features[element])
# Out:
# _____SPAM FEATURE_____
# ltgt
# ill
# home
# work
# later
# said
# lor
#
# still
# ok
# come
# mail
# princess
# watch
# happen
# happi
# that
# go
# execut
# billion
# sorri
# doesnt
# yeah
# much
# cant
# didnt
# good
# plan
# alway
# anyth
# also
# problem
# pick
# finish
# someth
# told
# know
# thanx
# say
# sure
# need
# how
# gonna
# mean
# she
# food
# hope
# right
# morn
# reach
# care
# alright
# aight
# meet
# realli
# wat
# long
# type
# cool
# alreadi
# might
# haha
# sleep
# sunday
# ltdecimalgt
# thank
# sir
# detail
# wonder
# money
# havent
# angri
# fine
# month
# list
# machan
# amp
# normal
# late
# pa
# email
# ye
# lunch
# dont
# resend
# fuck
# dinner
# monday
# decid
# oki
# lt3
# miller
# ask
# cream
# thought
# nice
# prob
# oredi
# dunno
# love
# head
# sweet
# room
# ive
# hold
# leav
# tuesday
# hous
# tomorrow
# yesfrom
# excel
# remb
# textin
# itc
# hav2hear
# abelu
# aphexåõ
# albumquit
# nolistened2th
# sicomo
# plaid
# gdthe
# air1
# compofstuff
# boughtåóbraindanceåóa
# hilariousalso
# prix
# funer
# born
# tocallshal
# ileav
# enufcredeit
# desper
# expert
# heater
# stevelik
# homewot
# inmind
# recreat
# scous
# manki
# virgil
# ha
# heavi
# tonitebusi
# dearshal
# ollubut
# edukkukaye
# okvarunnathu
# raksha
# streetshal
# toniteth
# yesim
# sentenc
# haiz
# lolnic
# mmmm
# haiyoh
# scienc
# greatby
# drinkin
# dancin
# space
# approx
# tick
# tortilla
# daili
# tamilnaduthen
# govtinstituit
# public
# housemaid
# closedinclud
# thx
# talkin
# goneu
# newquaysend
# boutxx
# yeahand
# chikkugo
# urin
# repair
# payoh
# colleagu
# steamboat
# thisdon
# daalway
# dahe
# messagepandi
# mandan
# appi
# contain
# fizz
# noisi
# suprem
# meat
# husband
# beg
# color
# satì
# hrishi
# aaooooright
# nicenicehow
# bit
# cartoon
# ima
# avent
# goggl
# hmmmkbut
# coher
# twenti
# hmmmi
# bloodi
# elect
# crush
# somewhr
# exhaust
# nic
# canlov
# friendsar
# thekingshead
# petey
# wherear
# someplac
# evil
# inperialmus
# listening2th
# byåóleafcutt
# johnåósound
# insect
# molestedsomeon
# plumbingremix
# acid
# jabo
# lorw
# vidnot
# finishd
# honeydid
# gossx
# gimmi
# januari
# parco
# vill
# common
# yovil
# ooooooh
# initi
# cell
# rule
# stretch
# student
# bollox
# basic
# durban
# naseeb
# zindgi
# pehl
# kisi
# zyada
# miltazindgi
# socht
# jeetey
# waqt
# kuch
# thankyou
# tvhe
# vijaykanth
# vitamin
# deartak
# may
# templ
# church
# multi
# heartheart
# 4some1
# bloodblood
# redr
# archiv
# lifebook
# silenc
# yesbut
# geeee
# thatnow
# west
# frndship
# blog
# magicalsongsblogspotcom
# websitenow
# sheffield
# cappuccino
# immunis
# salesman
# seat
# mrt
# nver
# cozsomtim
# investig
# black
# frndsship
# shoreth
# shopw
# qatarrakhesh
# indianpl
# numberrespect
# sirsalam
# alaikkumprid
# prestig
# belliger
# advanc
# bruv
# esaplanad
# sleepwellamptak
# ccna
# gain
# dajst
# fishhead
# claypot
# porridg
# chinatown
# beehoon
# sundayish
# de
# himso
# thanxxx
# 2go
# faultf
# faultal
# thin
# shatter
# greatest
# defeat
# heartgn
# cme
# elain
# netflix
# bambl
# entrop
# oblising
# nowaday
# notixiqu
# amplikat
# fidalf
# opt
# junna
# champlaxig
# atroci
# wotz
# laxinorf
# masteriast
# mentor
# percent
# wicket
# steyn
# appt
# nurseri
# inspect
# vtire
# conform
# yifeng
# two
# ywhere
# al
# dogbreath
# cheeto
# scold
# island
# diskyou
# ubandu
# fave
# posit
# sooner
# iåõm
# essenti
# courag
# goodenviron
# terrif
# journey
# infect
# oil
# massag
# dismay
# chiong
# stuff
# astoundingli
# acknowledg
# oath
# tactless
# theseday
# mutat
# sunscreen
# tiempo
# buen
# pase
# mini
# applebe
# human
# prolli
# complet
# cut
# buffet
# eachoth
# sam
# mindi
# toleratbc
# comfort
# sathya
# wale
# ibm
# carpark
# eightish
# officeunderstand
# nbme
# harder
# 215
# rearrang
# starer
# dormitori
# motherinlaw
# hitler
# eleven
# astronom
# recount
# swatch
# baaaaaaaab
# discount
# timin
# carlin
# pint
# flatter
# faggi
# tea
# bother
# keen
# lovem
# opportun
# cousin
# justbeen
# overa
# mush
# oxygen
# roller
# resort
# aft
# deari
# childish
# blood
# problemat
# abbey
# xoxo
# rawr
# spark
# soul
# shja
# terribl
# walkabout
# waitshould
# palm
# secondari
# sopha
# ogunrind
# thriller
# appeal
# karnan
# 1st
# computerless
# spatula
# gossip
# nevamindw
# justthought
# iåõd
# sayhey
# 2hook
# uwant
# doinnearli
# endof
# lovejen
# offdam
# cherish
# dump
# heap
# low
# wesley
# mise
# sfrom
# troubleshoot
# processit
# reset
# manual
# missionari
# û
# mee
# maggi
# kicchu
# kaaj
# parchi
# kort
# iccha
# korch
# cheesi
# frosti
# bold2
# lorgoin
# hypertens
# oooooh
# truekdo
# ssnervou
# everyday
# poke
# banter
# bridgwat
# callon
# chord
# snicker
# secretari
# askin
# director
# xin
# facil
# velusami
# peteynoiåõm
# timehop
# amx
# alritehav
# ge
# iti
# wifedont
# toolet
# flavour
# often
# magic
# shave
# kitti
# oni
# tirunelvali
# logoff
# promin
# cheek
# ron
# hollalat
# avalarr
# superior
# wise
# dictionari
# shouldnt
# ibuprofen
# colour
# wocay
# 2morrowxxxx
# 4eva
# pocay
# canada
# profil
# trash
# ofcours
# main
# clue
# surnam
# plate
# leftov
# ull
# champ
# glasgow
# itll
# clash
# thgt
# viva
# gmgngegnt
# edison
# rightli
# refer
# alreadysabarish
# brotherû÷
# misfit
# barrel
# scrape
# spinout
# boatin
# juswok
# 850
# 650
# naal
# eruku
# walmart
# dudett
# loti
# loverakhesh
# youdearwith
# categori
# transcrib
# ethnic
# censu
# cultur
# sprint
# reaction
# speechless
# four
# mca
# staff
# amrita
# sometm
# remet
# juan
# anni
# robinson
# marriageprogram
# chikkuali
# yalru
# vargu
# meow
# astn
# bilo
# halla
# meowd
# mundh
# innu
# edha
# taunton
# itu
# proverb
# japanes
# itleav
# caller
# mention
# tih
# holla
# wheellock
# woulda
# nyc
# hyde
# walik
# decim
# browni
# either
# onedg
# paragraph
# 10
# minu
# atm
# violenc
# pant
# olowoyey
# uscedu
# argentina
# snatch
# unsold
# playerwhi
# complain
# necklac
# wereth
# monkeespeopl
# monkeyaround
# howdi
# sausagelov
# howu
# foundurself
# jobyet
# 24th
# watt
# semiobscur
# bone
# familiar
# 98321561
# uncomfort
# post
# gudk
# xxxxxxx
# 2nhite
# basqihav
# drum
# dancc
# edrunk
# senrddnot
# pthi
# hellodrivby0quit
# spin
# bat
# chuck
# strang
# 3db
# shrek
# paragon
# outhav
# ffffffffff
# properli
# map
# witot
# vava
# availablei
# tackl
# reserv
# thirunelvali
# evei
# netno
# lower
# gota
# babesozi
# culdnt
# talkbut
# wannatel
# wenwecan
# past
# comput
# green
# dayexcept
# thatll
# langport
# chapel
# frontiervil
# lotwil
# yummmm
# hor
# bunker
# creepi
# convinc
# hourish
# checkup
# smear
# spiritu
# flood
# eight
# gower
# åômorrow
# memori
# bak
# lucyxx
# frndz
# 6miss
# misscal
# entertain
# mouth
# spile
# broad
# canal
# underwear
# yellow
# poci
# jolli
# blake
# film
# apologis
# dado
# describ
# tomarrow
# fair
# huai
# nusstu
# domain
# specifi
# diesel
# sayi
# toldsh
# brah
# omw
# liter
# frndshp
# luvd
# squeeeeez
# cali
# weddin
# simul
# clarif
# ruin
# imposs
# sunroof
# flea
# inperson
# enjoyin
# sack
# malaria
# gotten
# satsgettin
# 447per
# paracetamol
# mittelschmertz
# usno
# chennaii
# badrith
# groovi
# hogli
# madstini
# kodthini
# mutai
# eerulli
# kodstini
# hogolo
# nevil
# phil
# sleepi
# needa
# randomlli
# meremov
# envelop
# godyou
# 9pm
# nvm
# teeth
# unrecogn
# nevr
# somon
# undrstnd
# definitli
# remembr
# comprehens
# carlosl
# kappa
# crisisspk
# iknow
# wellda
# peril
# studentfinanci
# rubber
# l8tr
# 2mwen
# fonin
# nytho
# wrld
# mo
# spunout
# frmcloud
# north
# carolina
# texa
# shahjahan
# shld
# postpon
# queen
# needi
# haf
# freind
# tunji
# unconvinc
# willpow
# somerset
# hut
# bookedth
# amk
# storelik
# cereal
# aris
# agesr
# neth
# satlov
# thewend
# wotu
# iwana
# itxt
# theacus
# downon
# ey
# haventcn
# prasad
# tel
# uni
# accentur
# hhahhaahahah
# leonardo
# meaning
# slipperi
# trainner
# carryin
# chuckin
# view
# drinkpa
# gek1510
# motherfuck
# moan
# oclock
# bash
# thk
# chain
# carewhoev
# fundament
# boo
# parachut
# 645pm
# pear
# chest
# degre
# ago
# 2hr
# rout
# ish
# clever
# prospect
# franxx
# brolli
# cardiff
# ebay
# cram
# telugutht
# priscilla
# left
# centr
# rencontr
# petei
# jenni
# leannewhat
# wheel
# dabbl
# newscast
# roll
# flute
# wendi
# hole
# philosoph
# gari
# miiiiiiissssssssss
# dubsack
# princ
# shove
# ny
# rajitha
# ranju
# press
# correctli
# slot
# likeyour
# xxxxx
# satsoundåõ
# countinlot
# okden
# werebor
# mecaus
# gr8fun
# yupz
# bodi
# essay
# nose
# market
# sorryin
# thatû÷
# teas
# officestil
# formsdon
# tens
# mrur
# heåõ
# strangersaw
# stayin
# dave
# 2getha
# nowstil
# mountain
# pongaldo
# gd
# evrydi
# happili
# lttr
# truck
# aproach
# propsd
# thm
# threw
# msgsd
# girld
# 2gthr
# everytim
# 430
# boggi
# biatch
# nudist
# alcohol
# display
# hit
# moral
# registr
# begun
# perman
# resid
# inch
# complac
# lot
# jenxxx
# bedbut
# thepub
# hunnyjust
# bellearli
# uwana
# didntgiv
# slide
# embassi
# taka
# thanksgiv
# waheeda
# hidid
# kote
# kkthi
# gaug
# lodg
# hill
# reboot
# nigh
# corvett
# texd
# hopeu
# hellogorg
# 4ward
# cin
# nitw
# gosh
# spose
# thesi
# juici
# pretend
# jack
# hypotheticalhuagauahahuagahyuhagga
# sayask
# resiz
# chocol
# form
# consent
# commit
# patti
# alivebett
# uncount
# panti
# chez
# tadaaaaa
# astrolog
# dizzamn
# suitem
# quiet
# prepaid
# keralacircl
# refil
# guild
# sunoco
# cannt
# borderlin
# hearin
# westshor
# muhommad
# penni
# sporad
# contract
# charm
# europ
# burial
# fedex
# disast
# hurrican
# erupt
# aroundn
# sway
# volcano
# newport
# nationwid
# xx
# drove
# intend
# 4ui
# careabout
# itried2tel
# urmomi
# iwasmarinethatåõ
# postal
# alrightokay
# addressul
# previou
# printer
# carso
# babyjontet
# wouldnt
# attack
# asthma
# jstfrnd
# dayu
# clos1
# lifpartnr
# lvblefrnd
# cutefrnd
# best1
# dear1
# bstfrnd
# swtheart
# teju
# enemi
# leafdayno
# 1appledayno
# 1tulsi
# 1lemondayno
# litr
# milkdayno
# problm
# watrdayno
# diseas
# 1cup
# lesser
# hari
# known
# imagin
# promptli
# honestli
# burnt
# fret
# thanx4
# soonc
# yar
# ovul
# height
# chapter
# came
# iron
# express
# entrepreneur
# gn
# misundrstud
# admin
# cuti
# riley
# heroi
# opportunitypl
# ltemailgt
# addict
# charl
# gate
# goodfriend
# forevr
# sorrow
# hppnss
# evr
# academ
# nanni
# parentnot
# nonetheless
# itsnot
# nottingham
# 40mph
# 63mile
# craigslist
# treadmil
# godi
# youclean
# bloodsend
# itplspl
# yuou
# spot
# loos
# forfeit
# steak
# curiou
# chillin
# geelat
# aust
# personmeet
# onam
# insha
# allahrakhesh
# callingforgot
# sirjii
# tisscotays
# tata
# parkin
# gram
# vikki
# jontin
# aliv
# shindig
# therel
# corpor
# kavalan
# shoe
# selfless
# chennaibecaus
# intellig
# hanger
# goodnoon
# pool
# jacuzzi
# nurs
# obes
# oyea
# teacher
# meatbal
# digi
# cam
# coupla
# a30
# divert
# wadebridgei
# shini
# arnt
# xxxxxxxxxxxxxx
# belt
# hat
# cribb
# jumper
# wahleykkumshar
# newsbi
# tayseertissco
# joinedhop
# fineinshah
# allahmeet
# sometimerakheshvisitor
# salam
# grab
# refresh
# dawn
# absolut
# surgic
# unfold
# insur
# graviti
# goodnit
# pale
# beneath
# emerg
# leagu
# individualtim
# cope
# feelingwav
# heal
# constant
# slightli
# hehe
# shexi
# moyep
# sall
# aid
# patent
# scari
# rajipl
# nimya
# slap
# rebtel
# firefox
# court
# olav
# mandara
# trishul
# goodfin
# whenevr
# youani
# oursso
# drastic
# shopth
# weightloss
# boooo
# dem
# bead
# againcal
# uslet
# mindsetbeliev
# upseti
# macha
# twin
# oga
# skateboard
# thrown
# bandag
# bull
# float
# mess
# wahay
# hadnt
# lamp
# 2when
# doingwhat
# hellohow
# meaningless
# fightng
# dificult
# priya
# deduct
# careinsha
# maili
# varma
# membershiptak
# matric
# gudnit
# toss
# gudni8
# sourc
# gayd
# theoret
# hors
# improv
# 1843
# 1680
# 1405
# lag
# sittin
# glori
# fade
# ralph
# faitheven
# dayha
# hopeafternoon
# luvnight
# restwish
# todaygood
# valuemorn
# bimbo
# ugo
# whenr
# shouldnû÷t
# bû÷ham
# triumph
# brave
# allo
# becoz
# explain
# kinda
# dough
# gover
# petrol
# decad
# 9t
# wasnåõt
# spous
# shldxxxx
# sumthin
# 4give
# empti
# prometazin
# syrup
# 5ml
# feed
# depress
# hererememb
# muchand
# latei
# theregoodnight
# venugop
# dileepthank
# supportveri
# mentionedtomorrow
# blank
# lubli
# flake
# 8attract
# 7shi
# 6romant
# 9funni
# 4rowdi
# 3sentiment
# 1childish
# attitud
# 2naughti
# 5ful
# cedar
# ifink
# sortedbut
# melnit
# 2nitetel
# everythin
# monl8rsx
# every1
# goodtimeoli
# hunnywot
# bedroomlov
# rhythm
# solv
# 2bajarangabali
# 6ramaduth
# matra
# olag
# janarig
# 7mahav
# 3maruti
# neglet
# siguviri
# hanumanji
# 4pavanaputra
# odalebeku
# ondu
# 1hanuman
# kalisidar
# keluviri
# nalli
# maretar
# ind
# dodda
# ivatt
# poortiyagi
# problum
# 5sankatmochan
# practicum
# ear
# consist
# blur
# crisi
# walkin
# arngd
# unfortuntli
# frnt
# sayin
# easili
# confid
# answerin
# shrink
# ovarian
# cyst
# all
# bcozi
# button
# dick
# vomit
# control
# eckankar
# lanr
# fakey
# elliot
# engalnd
# breez
# twitter
# fresh
# asia
# heartsnot
# dont4get2text
# aiya
# beth
# charli
# gymnast
# chad
# christian
# melt
# atyour
# jeremiah
# cocksuck
# novelti
# worthless
# satisfi
# okor
# vagu
# ahhh
# bowa
# featheri
# ìïll
# ar
# soc
# fortun
# doesnåõt
# up
# moneyi
# tomorrowtoday
# engag
# blimey
# exercis
# backa
# token
# youthat
# likingb
# seeno
# thatdont
# somtim
# prsn
# smokin
# nicki
# sacrific
# coat
# stripe
# skirt
# tesco
# abstract
# mear
# slaaaaav
# summon
# cabin
# rudi
# snoringthey
# shrub
# foreg
# worc
# shame
# fridayhop
# alternativehop
# num
# yell
# scrappi
# grumpi
# asda
# tosend
# lifei
# daywith
# somewheresomeon
# miser
# workag
# spif
# salespe
# steam
# msging
# woah
# beach
# drizzl
# vital
# lautech
# sagamu
# shola
# zealand
# atten
# unhappi
# comingtmorow
# bfore
# starti
# cherthalain
# accordinglyor
# dearm
# mapquest
# dogwood
# tini
# luckili
# sathi
# christmasmerri
# possiblehop
# faith
# beautifulmay
# worklov
# citizen
# mt
# shijutta
# prabha
# theori
# brum
# poem
# pend
# membership
# yaxxx
# hunlov
# worryc
# wrongtak
# gail
# abus
# derp
# women
# tomorro
# restock
# batch
# buzzzz
# xuhui
# attach
# appendix
# gyno
# gray
# whileamp
# watevr
# listn
# loud
# belong
# galno
# boyi
# princegn
# heaven
# galcan
# throwin
# strtd
# moraldont
# atlast
# fishrman
# 1stone
# missin
# fite
# hwkeep
# met
# sweeti
# wlcome
# state
# pubcaf
# 1526
# sian
# victor
# winterston
# stagwood
# ifwhenhow
# oz
# firesar
# scroung
# lotr
# piah
# fulfil
# breather
# grant
# conect
# 4few
# needl
# meetitz
# jerri
# tram
# stick
# ultimatum
# countin
# aburo
# lareadi
# pull
# restuwud
# reliant
# bid
# ach
# interfu
# flip
# everywher
# agent
# alwi
# joanna
# establish
# studentsthi
# datz
# aeroplan
# calld
# professor
# aeronaut
# saidif
# 96
# length
# gua
# faber
# law
# pendent
# slurp
# theyll
# youû÷ll
# receiptsûówel
# whatû÷
# medont
# 1hi
# 2polic
# 5garden
# 8neighbour
# 7children
# veget
# siri
# 4cook
# 3wife
# 6housemaid
# cooper
# adjust
# particip
# gopalettan
# reject
# thatd
# scenario
# slove
# tookplac
# ghodbandar
# wasnû÷t
# shortag
# lacsther
# lacsthat
# urgentbut
# arng
# urgentlyit
# amt
# rel
# dearer
# looovvv
# trek
# sink
# pace
# cuck
# surround
# cage
# bb
# nelson
# okday
# 1230
# olol
# forgt
# judgementali
# prey
# yesher
# ape
# youåõr
# coccoon
# mineal
# annoyin
# yeesh
# temp
# endow
# beneficiari
# neft
# ahmad
# grow
# nightswt
# dreamstak
# weapon
# huim
# pie
# tight
# motor
# max
# yeovil
# 2im
# trubl
# evon
# sheet
# bottl
# amus
# epi
# andor
# gastroenter
# reduc
# heavili
# desir
# liver
# shock
# smeon
# forc
# irulina
# sneham
# prakasamanu
# neekunna
# islov
# ennal
# jeevithathil
# prakasam
# presnt
# reltnship
# wipe
# timegud
# dialogu
# misbehav
# sooooo
# half
# brat
# eventu
# toler
# although
# zoom
# sucker
# infront
# didnû÷t
# persev
# nighter
# oral
# taylor
# mous
# desk
# flung
# pract
# swan
# accumul
# wenev
# vivekanand
# battl
# sd
# taxi
# involv
# selfish
# passthey
# shesil
# ntswt
# drm
# devour
# creativ
# fowler
# lauri
# hugh
# bay
# ray
# ortxt
# wreck
# somewhat
# laden
# knee
# hooch
# toaday
# splat
# graze
# brin
# pooki
# fresher
# processexcel
# mssuman
# indyarockscom
# neededsalari
# via
# fwiw
# afford
# ham
# hairdress
# beforehand
# failur
# bawl
# nosh
# 8830
# gmgngegn
# havnt
# crack
# honeybe
# waitu
# sweetest
# front
# eta
# nacho
# amigo
# idk
# bluff
# bthere
# fromwrk
# 2watershd
# towncud
# adrink
# outsomewher
# petexxx
# wedlunch
# french
# disastr
# consensu
# foward
# simpler
# zhong
# qing
# splash
# massiv
# bleak
# quarter
# lovin
# tact
# nightnobodi
# cozi
# phew
# stair
# trade
# arul
# blame
# bthmm
# fixd
# sudn
# vilikkamt
# njan
# der
# ericson
# modl
# luk
# modelsoni
# slob
# snowboard
# goa
# disc
# hillsborough
# heron
# lindsay
# ptbo
# perfum
# goigng
# myspac
# piggi
# obedi
# easter
# approach
# tahan
# anot
# 2godid
# nauseou
# sarcast
# onit
# thou
# dread
# 5iåõm
# stubborn
# wisdom
# impost
# itmay
# destini
# priceso
# mene
# satan
# youso
# hidden
# tobe
# stil
# mushi
# embarrass
# pendingi
# dayswil
# thrurespect
# homecheck
# kettoda
# manda
# affect
# wate
# 415
# dysentri
# camri
# kit
# mileag
# olayiwola
# toyota
# shoul
# 515pm
# toughest
# sip
# starshin
# cri
# dearli
# 8hr
# brisk
# clean
# ummmmmaah
# data
# analysi
# hallaq
# jolt
# hustl
# forth
# harlem
# avin
# africa
# kane
# shud
# bong
# rhode
# diaper
# owe
# afternon
# accordin
# leona
# weekday
# nail
# attribut
# shitstorm
# wuldnt
# ilol
# recognis
# replyb
# frankgood
# resolut
# twigg
# affidavit
# courtroom
# sumthinxx
# batt
# knowyetund
# impos
# 730pm
# versu
# grate
# superb
# happier
# get4an18th
# tightli
# unmit
# guilti
# underdtand
# edg
# unspoken
# nit
# soonxxx
# darlinim
# 2morrow
# paranoid
# tooo
# someonethat
# seperatedö´óû¬ud
# tonght
# ahold
# donew
# haul
# wifi
# grownup
# stuffwhi
# pride
# muchimped
# fiendmak
# dsnt
# prone
# imaginationmi
# poet
# todaybut
# soooo
# agenc
# behalf
# stun
# hiphop
# salad
# visitne
# finalis
# daysso
# monster
# particularli
# torrent
# afterward
# syria
# eighth
# smarter
# awww
# spi
# takecar
# wthout
# dearlov
# 4wrd
# espel
# neces
# watll
# hwd
# witout
# reslov
# inst
# overh
# board
# doke
# pressur
# couch
# loooooool
# thu
# alsoor
# usget
# lifey
# overemphasiseor
# sensesrespect
# timeyour
# convers
# wellyou
# thati
# portal
# hungov
# grandma
# boyf
# worriedx
# exet
# interviw
# snog
# unusu
# neither
# signal
# jenn
# wudnt
# least5tim
# smoothli
# spontan
# goodeven
# fuell
# shoranur
# fate
# herwho
# concern
# prior
# grief
# smiley
# hisher
# pure
# drunkard
# outif
# greec
# haunt
# notebook
# welli
# uothrwis
# prayr
# wordsevri
# uso
# evri
# emot
# mad
# upset
# upsetit
# oblivi
# julianaland
# brighten
# spageddi
# messi
# darker
# pour
# intrud
# xavier
# samantha
# guitar
# doug
# spirit
# becz
# undrstndng
# grumbl
# plough
# chinki
# pile
# split
# sensibl
# conduct
# againlov
# unemploy
# 6pm
# casualti
# stuff42moro
# baig
# entir
# spreadsheet
# deer
# ovulatewhen
# 3wk
# heltiniiyo
# meok
# chikkub
# yalrigu
# meso
# nap
# strict
# ditto
# sq825
# determin
# but
# delici
# arpraveesh
# embarass
# eek
# flurri
# ground
# western
# yould
# teresa
# usml
# cave
# young
# fold
# ritten
# sleepin
# laundri
# mist
# chore
# dirt
# hail
# exist
# herlov
# heri
# dime
# awkward
# bend
# preview
# thia
# inlud
# unit
# 4year
# dental
# nmde
# accent
# attractioni
# namemi
# hermi
# herwil
# sorrowsi
# hersh
# mesh
# dreamlov
# sambarlif
# proov
# maki
# thenwil
# prais
# thoughtsi
# planeti
# 2year
# strain
# crowd
# 83021
# fastest
# 08714712412
# 08714712379
# feb
# recess
# henc
# inconsider
# visa
# gucci
# bra
# strewn
# pillow
# machin
# 08714712394
# curfew
# gibe
# getsleep
# studdi
# woul
# 2waxsto
# ownyouv
# visitor
# followin
# subscrit
# splashmobil
# organ
# psychiatrist
# healer
# stylist
# aaniy
# pudunga
# boyfriend
# athlet
# sympathet
# companion
# psychologist
# venaam
# chef
# pest
# extermin
# help08714742804
# club4
# box1146
# club4mobilescom
# 87070
# stream
# polyc
# monoc
# 0871212025016
# 09064017295
# 09061790125
# ukp2000
# 1146
# gbp450week
# html
# 23
# mytonecomenjoy
# mk45
# 09058094455
# 09058094454
# norm
# 09061790121
# delhi
# supli
# deposit
# karo
# monthli
# itna
# padhegm
# pura
# taxless
# corrupt
# eå£nd
# 3xå£150pw
# 2814032
# 08714719523
# 10803
# swiss
# politician
# yr
# crore
# msgs150p
# 087123002209am7pm
# 087147123779am7pm
# 2stoptx
# dracula
# ghost
# twilight
# addamsfa
# munster
# exorcist
# tip
# wap
# hero
# receivea
# 09061701461
# kl341
# call2optoutf4q
# www07781482378com
# prizeto
# upd8
# 10am9pm
# 6031
# call2optoutyhl
# pdatenow
# call2optouthf8
# becausethey
# w14rg
# 09058098002
# pobox1
# accid
# box42wr29c
# 09064019788
# 5903
# spanish
# win150ppmx3age16
# gb
# 20m12aq
# call2optout674
# 09058094507
# str
# 4txt120p
# 0870141701216
# call2optout4qf2
# dvd
# 3030
# wwwldewcom1win150ppmx3age16subscript
# 74355
# 09061701939
# s89
# 12hour
# k61
# 09061701851
# box39822
# w111wx
# 84199
# 08718729758
# 07808726822
# 08718729755
# speed
# chosen
# 09066364311
# 09094646899
# bcm1896wc1n3xx
# 0721072
# 087016248
# celeb
# 0808
# 4742
# 9am11pm
# call2optoutlf56
# 3650
# 09066382422
# 300603
# bcm4284
# m263uz
# phoni
# ph08704050406
# sprwm
# 80122300pwk
# snap
# quizclub
# box245c2150pm
# j89
# 09050000460
# iscom
# 09061743811
# repres
# apply2
# sonyericsson
# 27603
# 08714714011
# 09064018838
# cro1327
# 020903
# httpwwwetlpcoukexpressoff
# 09050003091
# c52
# box95qu
# bcmsfwc1n3xx
# 69969
# competit
# r836
# k718
# 09065069154
# 09065069120
# k52
# 09064012160
# gent
# rg21
# php
# funki
# m95
# 09050001808
# tones2u
# funk
# poly200p
# nokia150p
# classic
# str8
# 09050000555
# ba128nnfwfly150ppm
# 10th
# 08002986906
# lion
# pobox202
# nr31
# 450pw
# 08717898035
# eh74rr
# 177
# voucherstext
# nowsavamobmemb
# compens
# 12hr
# tiger
# profession
# wood
# tsandc
# 6day
# 150pday
# csh11
# 20000
# wait
# luxuri
# canari
# valid12hr
# 9996
# availa
# 14thmarch
# there
# straight
# colourredtextcolourtxtstar
# x49
# randi
# femal
# 08700621170150p
# x49your
# www80488biz
# 09065989180
# x29
# å£300
# 85023
# whose
# 150ppmpobox10183bhamb64x
# 09071517866
# 62220cncl
# stopc
# 08717890890å£150
# nowsend
# wwwtklscom
# stoptxtstopå£150week
# 09061702893
# getstop
# cashto
# 88222
# 08000407165
# cheaper
# spjanuari
# 7732584351
# 08702840625
# gotto
# comuk220cm2
# 09050000332
# httpwwwgr8prizescom
# wktxt
# 8800
# gr8prize
# 08708800282
# lionp
# lionm
# 3750
# stamp
# 07732584351
# rodger
# efreefon
# 32000
# legitimat
# 07742676969
# 08719180248
# 45239
# wa14
# complementari
# sender
# 09066361921
# knock
# box420
# help08700469649
# 09065989182
# 09061749602
# hp20
# hot
# packag
# 09066649731from
# 09066660100
# 2309
# 3gbp
# wwwringtonescouk
# seem
# 3lion
# 241
# ltdhelpdesk
# 02085076972
# strt
# 81010
# lccltd
# å£100000
# jackpot
# wwwdbuknet
# 4403ldnw1a7rw18
# 08002986030
# 89105
# neo69
# fraction
# backdoor
# hack
# dp
# 8027
# 09050280520
# 09061743810
# indic
# remind
# upgrdcentr
# 9153
# costå£375max
# 09061104276
# concert
# novemb
# flag
# mind
# heart
# cw25wx
# 09066612661
# held
# 8077
# male
# peak
# 08709222922
# 15pmin
# 78pmin
# children
# zed
# 077xxx
# 09066362206
# hardcor
# 69200
# chrgd50p
# 2exit
# vpod
# 450
# 01223585334
# 2end
# 09066362220
# help08712400602450p
# tones2youcouk
# 61610
# bank
# 5000
# freefon
# 0207
# 0871277810710pmin
# 08006344447
# 69669
# gpr
# 1172
# å£150msg
# 69696
# villa
# 2wk
# spiderman
# marvel
# 8ball
# 83338
# spider
# sim
# deliveredtomorrow
# address
# wkend
# someonon
# 09064015307
# smartcal
# 68866
# 1month
# subscriptn3gbpwk
# landlineonli
# stoptxt
# 08448714184
# high
# po19
# 0906346330
# hava
# 1131
# 5226
# 09061213237
# m227xi
# 08707500020
# realiti
# jordan
# 3680offer
# 28thfebtc
# lover
# 83435
# 82324
# 4041
# 7548
# cr01327bt
# 09064011000
# 10k
# fixedlin
# 09111030116
# conact
# youto
# pobox12n146tf15
# 449071512431
# sexiest
# dirtiest
# night
# rpli
# 09058097189
# 97n7qp
# 09066368753
# 100603
# 8000930705
# entitl
# frnd
# txting
# hmv1
# 2stoptxt
# total
# learn
# wither
# eg23g
# eg23f
# alon
# verifi
# tariff
# 08452810073
# 80182
# 3ss
# rstm
# self
# brows
# artist
# 07808
# xxxxxx
# 08719899217
# howev
# wwwldewcom1win150ppmx3age16
# 8552
# 08717507382
# 13404
# dept
# 09064017305
# pobox75ldns7
# 09063442151
# 0089mi
# channel
# 87021
# password
# 08715203649
# 07973788240
# 0871277810810
# cast
# 181104
# 07815296484
# 41782
# scotland
# 261004
# 08715203656
# 42049
# abta
# mustprovid
# accommodationvouch
# 62735å£450
# 83039
# 15541
# 10p
# recdthirtyeight
# questionstd
# 08452810075over18
# ratetc
# 21st
# skip
# choic
# 08715203694
# 09050005321
# 08719899230
# sign
# moon
# rp176781
# 08717205546
# wwwregalportfoliocouk
# 49557
# 261104
# deltomorrow
# 2006
# fifa
# 07xxxxxxxxx
# 07753741225
# 08715203677
# 42478
# 241004
# motorola
# freerington
# real1
# pushbutton
# dontcha
# webeburnin
# golddigg
# babygoodby
# wwwtextpodnet
# textpod
# 09063440451
# 4lux
# ppm150
# box334
# matthew
# 08718726970
# box97n7qp
# 300p
# 10ppm
# promo
# 08712402050
# 123
# 09050002311
# b4280703
# tcsstop
# 08718727868
# å£1450
# 2optoutd3wv
# 12price
# btooth
# mins100txtmth
# xnet
# panason
# bluetoothhdset
# doublemin
# doubletxt
# import
# 6month
# call2optoutn9dx
# breathe1
# ymca
# getzedcouk
# pobox365o4w45wq
# crazyin
# finest
# sleepingwith
# 09066350750
# 10000
# 08715500022
# shi
# 09058091870
# previous
# homeown
# å£75000
# 1956669
# 350
# 08718726270
# customercar
# 150pmsgrcvd
# messagethank
# 08706091795
# helplin
# 09057039994
# t91
# activ8
# rayman
# termsappli
# golf
# download
# 08718730666
# floppi
# snappi
# enough
# box61m60
# 09094100151
# gbp5month
# aom
# 08450542832
# 84122
# notifi
# callback
# textsweekend
# orno
# tarot
# 85555
# harri
# å£10000
# 89070
# serv
# 08702490080
# phone750
# bear
# ibiza
# å£750
# 087187272008
# now1
# paid
# dream
# 4utxt
# chatim
# w8in
# etc
# websit
# nytec2a3lpmsg150p
# horniest
# inclus
# 125gift
# å£1million
# ppt150x3normal
# box403
# w1t1ji
# heard
# 3510i
# 08719839835
# ukmobiled
# 89123
# updat
# found
# gold
# purchas
# 087018728737
# tune
# 81618
# toppoli
# pole
# skillgam
# 150ppermesssubscript
# wwwidewcom
# 1winaweek
# pay
# arrow
# babe
# wwwldewcomsubs161win150ppmx3
# kick
# provid
# hol
# review
# 087104711148
# code4xx26
# 08715203685
# 131004
# login
# 09066364589
# 09066368470
# 83355
# ibhltd
# ldnw15h
# 150pmtmsgrcvd18
# 09058095107
# s3xi
# 09066362231
# wwwb4utelecom
# marsm
# 2703
# 08717168528
# pink
# age
# wk
# 020603
# 113
# bray
# wicklow
# eir
# å£150week
# 2wu
# 139
# 08709501522
# recd
# futur
# 071104
# 41685
# respond
# 150pwk
# wwwtxt2shopcom
# 0871277810910pmin
# deal
# profit
# 09065174042
# 07821230901
# 69698
# 311004
# 40533
# tenerif
# 08718738001
# txtx
# la32wu
# web2mobil
# nowus
# txt250com
# messagestext
# box139
# smsservic
# yourinclus
# detroit
# strong
# 87131
# 09061744553
# polyh
# vari
# benefit
# 08702840625comuk
# 220cm2
# 0870737910216yr
# å£150wk
# 7250
# nichol
# 80878
# 08712101358
# someon
# wc1n
# 2667
# gsex
# gravel
# wwwgetzedcouk
# httpwwwwtlpcouktext
# httpwwwetlpcoukreward
# sticki
# suppli
# 18
# 3qxj9
# boltblu
# poly3
# toxic
# jamz
# mono
# wwwtelediscountcouk
# 5we
# bx420
# ip4
# diall
# 402
# advisor
# 84128custcar
# subsequ
# textcomp
# charged150pmsg2
# wwwrtfsphostingcom
# 69101
# wildest
# 2night
# touch
# talk
# hard
# 150pmt
# 07801543489
# wordcollect
# msgrcvd18
# no83355
# nyusa
# tcllc
# cmon
# flight
# airport
# bedroom
# lone
# surpris
# 08712405022
# 80608
# wwwmovietriviatv
# bought
# wwwmusictrivianet
# 83370
# wwwcomuknet
# eeri
# titl
# 3100
# 09701213186
# jamstercouk
# logosmusicnew
# videosounds2
# videosound
# 16onli
# wwwsmsacubootydeli
# no434
# yes434
# 32f
# bootydeli
# å£50award
# 1225
# olymp
# halloween
# 08701417012150p
# logop
# annonc
# 07046744435
# liverpool
# parti
# 84128
# day
# norm150pton
# w45wq
# 36504
# 1winawk
# tscs08714740323
# å£150perweeksub
# wwwldewcom
# deliv
# på£399
# warranti
# m221bp
# 28day
# box177
# 09061221061
# age16150ppermesssubscript
# skillgame1winaweek
# bird
# fone
# 08712460324nat
# 08712466669
# twink
# jock
# skin
# scalli
# five
# away
# 69888nyt
# bitch
# 2000
# abroad
# xxsp
# stopcost
# 08712400603
# die
# hear
# 0789xxxxxxx
# wwwflirtpartyu
# replys150
# 2channel
# wquestion
# psychic
# skill
# leadership
# anim
# 11mth
# ring
# set
# frogaxel
# coolmob
# eyeddont
# akonlon
# boy
# randomli
# promot
# cross
# optout
# instant
# å£50å£500
# 08715203028
# uûªv
# å£50
# 250
# inc
# survey
# secur
# med
# or2stoptxt
# 4mth
# 08000938767
# mobilesdirect
# 6230
# pobox11414tcrw1
# 83383
# unsub
# promis
# win
# 8714714
# tscs087147403231winawkage16
# å£150perwksub
# unlimit
# marri
# å£900
# 1st4term
# wire3net
# mobcudb
# 9061100010
# 83332pleas
# msgwe
# refundedthi
# shortcod
# 08081263000
# exp
# 30apr
# station
# meetin
# å£1500
# 09058094597
# 447801259231
# 08002888812
# unsecur
# 6669
# dine
# advis
# 0776xxxxxxx
# fromm
# 09061221066
# m8
# 08701417012
# alfi
# wwwsantacallingcom
# 09077818151
# calls150ppm
# 69888
# guess
# acl03530150pm
# voda
# 08712300220
# singl
# chart
# 82277unsub
# 008704050406
# cornwal
# duchess
# quizwin
# fall
# mix
# ton
# fast
# smart
# shop
# wow
# 09061701444
# hvae
# includ
# girl
# 0825
# amanda
# 3680
# subject
# record
# kickoff
# tcrw1
# 11414
# usher
# 85069
# britney
# 5249
# mk17
# 92h
# 450ppw
# qualiti
# 08000776320
# shracomorsglsuplt10
# 186å£150morefrmmob
# acoentry41
# trav
# eurodisinc
# 08718726971
# 08712103738
# 08718726978
# mysteri
# optin
# 60pmin
# recent
# euro
# polyph
# 09063458130
# algarv
# upto
# pobox84
# call09050000327
# ticket
# swat
# colin
# kiosk
# 4712
# msgticketkioskvalid
# popcornjust
# farrel
# 83118
# yes762
# no762
# wwwsmsacugoldvik
# 29m
# goldvik
# land
# 0845
# page
# xxuk
# sextextukcom
# dointerest
# 69876
# suzi
# prizeawait
# 0796xxxxxx
# day2
# 82468
# å£150pm
# 09061104283
# nowtc
# winnersclub
# 3uz
# gbp150week
# 85222
# lookin
# nat
# ecstaci
# 09095350301
# erot
# 08715705022
# part
# everi
# shag
# marley
# dizze
# racal
# libertin
# stroke
# nookii
# lastest
# stereophon
# bookmark
# countri
# wwwsmsconet
# 09065171142stopsms08718727870150ppm
# 09065171142stopsms08
# 09058094565
# 09058094594
# refus
# made
# www4tcbiz
# 89545
# å£1
# 08718726270150gbpmtmsg18
# cc100pmin
# upgrad
# anytim
# sugabab
# zebra
# wallpaperal
# themobhit
# hoodi
# badass
# panther
# cruis
# variou
# coupl
# definit
# tnc
# pari
# juli
# 87121
# capit
# orig
# o2coukgam
# invad
# consol
# along
# loyal
# 09066380611
# loung
# 08718727870
# 88600
# hurri
# yes910
# wwwsmsacuhmmross
# no910
# lyricalladie21f
# 2004
# hockey
# dorothykiefercom
# discreet
# freemsgfeelin
# lnli
# pictxt
# word
# store
# 31pmsg150p
# 0844
# prepay
# 40gb
# read
# 87575
# amaz
# 83110
# suit
# 08712405020
# 08704439680
# wanna
# savamob
# footi
# 3unkempt
# 2untam
# 83049
# westlif
# meetgreet
# wan2
# 1unbreak
# passion
# sub
# cock
# sw73ss
# 526
# british
# 02072069400
# 2morro
# 09061743386
# hunk
# httpgotbabescouk
# cannam
# mquiz
# australia
# bloke
# largest
# laid
# ec2a
# allow
# 09050000878
# pobox45w2tg150p
# wing
# devil
# jersey
# incorrect
# spook
# wwwsmsacunat27081980
# no440
# yes440
# 25f
# natalja
# 16
# energi
# 150pmeg
# hello
# elvi
# presley
# ever
# start
# cute
# lost
# instruct
# issu
# 2optout
# genuin
# infowww100percentrealcom
# cinema
# smash
# 2nite
# 150pmsgrcvdhgsuite3422landsroww1j6hl
# 18yr
# karaok
# bore
# minstext
# 4info
# 150ptone
# txtin
# compar
# violet
# lili
# wkent150p16
# eastend
# tulip
# penc
# å£3350
# garden
# bulb
# notxtcouk
# seed
# scotsman
# 2morow
# 150
# activ
# roww1j6hl
# pocketbabecouk
# look
# rentl
# nolin
# dload
# videophon
# java
# videochat
# 88877
# 88877free
# carli
# villag
# career
# 88039
# skilgm
# 7w
# otbox
# å£150ea
# string
# 89938
# 1mcflyall
# sara
# ab
# smithswitch
# jorgeshock
# 7876150ppm
# b4190604
# 09058099801
# wwwgambtv
# item
# vodafon
# 18onli
# match
# rgent
# retriev
# 21870000hi
# 09056242159
# mailbox
# g696ga
# banneduk
# georg
# jordantxt
# 89080
# celeb4
# free2day
# 0870241182716
# cocacola
# larg
# stadium
# continu
# rose
# sipix
# 8pm
# respons
# jsco
# extra
# ofå£2000
# 07786200117
# callfreefon
# 08081560665
# gnarl
# barkley
# 2rcv
# msg150p
# 08712317606
# wwwtxt43com
# 80160
# blow
# 150pmtmsg
# 4tctxt
# 81151
# nokia6650
# offerth
# soire
# m39m51
# å£150pmmorefrommobile2bremovedmobypobox734ls27yf
# unclaim
# 09066368327
# claimcod
# closingdate040902
# åòharri
# ûïharri
# 50
# break
# 1x150pwk
# sptyron
# ansr
# goalsteam
# poboxox36504w45wq
# 4txtì¼120
# trywal
# macedonia
# goto
# presid
# super
# uk
# 08718723815
# 449month
# call2optoutj
# avbl
# bundl
# txtno
# name1
# name2
# mobno
# 07123456789
# adam
# costa
# an
# å£350
# footbal
# 09050090044
# toclaim
# pobox334
# sae
# costå£150pm
# max10min
# stockport
# 7cfca1a
# tcsbcm4235wc1n3xx
# 050703
# 09071512433
# callcost
# å£1250
# mobilesvari
# mth
# prompt
# 09066358152
# tkt
# 08717507711
# housew
# btnation
# weekend
# wc1n3xx
# ringtoneget
# freesend
# 816183
# weekstop
# sms08718727870
# balanc
# standard
# sinc
# 80155
# chat80155
# chatter
# swap
# theyr
# score
# woman
# stopbcm
# 69855
# lucki
# releas
# lifetim
# å£3wk
# day2find
# polyphon
# kept
# 87066
# foley
# wwwwin82050couk
# plyr
# shinco
# notif
# acsmsreward
# outbid
# simonwatson5120
# cameravideo
# xxxmobilemovieclubcomnqjkgighjjgcbl
# httpwap
# xxxmobilemovieclub
# linerent
# complimentari
# tour
# msg
# porn
# 09058094599
# pack
# arrang
# 08001950382
# 3pound
# custcar
# custcare08718720201
# meal
# 6986618
# age23
# blond
# 30pptxt
# increment
# mila
# help08718728876
# 5free
# mtalk
# crazi
# team
# sk38xh
# 3hr
# stoptxtstop
# 86888
# subscribe6gbpmnth
# end
# 3min
# 09099726395
# cumin
# dirti
# 84025
# wwwtextcompcom
# virgin
# select
# chase
# quot
# incred
# o2fwd
# 18ptxt
# planettalkinstantcom
# cs
# 08448350055
# littl
# pass
# flyng
# ari
# 83222
# strip
# trackmarqu
# prebook
# infovipclub4u
# action
# 09058094583
# resubmit
# expiri
# receipt
# 08718730555
# send
# hotel
# eve
# havin
# borin
# subpoli
# 07099833605
# ref9280114
# reschedul
# valu
# janinexx
# daytim
# 09099726429
# busti
# ph08700435505150p
# global
# wwwphb1com
# accommod
# 81303
# asap
# 07734396839
# no81151
# now4t
# nokia6600
# txtauctiontxt
# wordstart
# textbuddi
# 89693
# gaytextbuddycom
# lkpobox177hp51fl
# 09099726553
# callså£1minmobsmor
# fink
# å£450
# 08717111821
# noworriesloanscom
# 28th
# netcollex
# citi
# warner
# thur
# tonex
# wwwclubzedcouk
# min
# within
# 08708034412
# 300603tcsbcm4235wc1n3xxcallcost150ppmmobilesvari
# å£1000call
# 09071512432
# ig11
# 1013
# account
# compani
# warm
# nation
# identifi
# unredeem
# play
# 2moro
# tenant
# purpos
# teletext
# reciev
# offer
# anyon
# year
# mega
# 09099725823
# 7250i
# roww1jhl
# mymobi
# httpdoit
# 08718720201
# congrat
# 09099726481
# dena
# å£1minmobsmorelkpobox177hp51fl
# block
# 87239
# locat
# buddi
# 88039skilgmetscs087147403231winawkage16å£150perwksub
# 285
# zouk
# parisfre
# xclusiveclubsaisai
# 0794674629107880867867
# 83600
# expir
# uve
# digit
# mobi
# handset
# hgsuite3422landsroww1j6hl
# sexual
# 69911å£150p
# 3mobil
# inclu
# l8er
# chatlin
# bailiff
# ldn
# updatenow
# 08000930705
# maxim
# cashin
# cashbal
# 25p
# itcould
# lucozad
# lucozadecoukwrc
# 61200
# code
# name
# local
# sing
# regist
# flirt
# live
# challeng
# god
# sun0819
# helloy
# hi
# std
# wwwtxt82228com
# infotxt82228couk
# text82228
# wwwtxttowincouk
# 80086
# call2optoutj5q
# 400minscal
# format
# mob
# secretli
# datebox1282essexcm61xn
# 09065394514
# 0870
# opinion
# camcord
# echo
# tripl
# help
# king
# 0870k
# txtauction
# 448712404000pleas
# 08712404000
# privaci
# star
# gift
# 150ptext
# chloe
# 08707509020
# bill
# center
# sptv
# 10am
# big
# 80062
# top
# 86021
# 08000839402
# 12mth
# 08712402578
# 08712402779
# 08712402972
# music
# perfect
# 88088
# gamestar
# nowski
# å£250k
# postcod
# 82277
# 82242
# tc
# chariti
# å£400
# loan
# croydon
# 1327
# announc
# 88888
# 08701213186
# lapdanc
# sue
# 150ppmsg
# sex
# å£2000
# symbol
# helen
# bblue
# simpson
# band
# agreen
# cred
# wallpap
# saturday
# experiencehttpwwwvouch4mecometlpdiningasp
# chg
# stop2stop
# wild
# videop
# 150prcvd
# horni
# sell
# graphic
# bbdelux
# featur
# delux
# breaker
# restrict
# question
# bx420ip45w
# starwars3
# 09061209465
# matrix3
# suprman
# ipod
# themob
# decemb
# pleas
# special
# xchat
# wkli
# england
# everyon
# breath
# mobileupd8
# newest
# member
# charg
# germani
# 300
# nasdaq
# explos
# 500
# per
# strongbuy
# granit
# cdgt
# arcad
# current
# rental
# doubl
# pobox36504w45wq
# 0anetwork
# supplier
# 150ppm
# fantast
# phoenix
# potter
# reader
# among
# å£500
# listen
# remov
# burger
# hubbi
# biggest
# network
# cust
# sale
# pound
# 2day
# chanc
# sic
# 09090900040
# extrem
# 247mp
# 0870753331018
# 08712460324
# 83738
# landmark
# barri
# bob
# å£600
# bahama
# wmlid1b6a5ecef91ff937819firsttrue180430jul05
# ringtonefrom
# order
# bonu
# simpli
# prizeswith
# dozen
# tddnewsletteremc1couk
# thedailydraw
# minapn
# aå£150
# 09090204448
# ls278bb
# 2005
# begin
# 08718711108
# 88800
# 89034
# euro2004
# congratul
# sec
# worth
# visionsmscom
# custom
# jamster
# mobstorequiz10ppm
# 08717895698
# httpwwwurawinnercom
# 09058097218
# å£800
# speedchat
# 2stop
# tcsc
# max6month
# monthlysubscription50pmsg
# wwwapplausestorecom
# realiz
# ls15hb
# 150pm
# request
# sauci
# 80488biz
# wwwtcbiz
# polo
# bloombergcom
# httpcareer
# 447797706009
# bloomberg
# subscript
# line
# å£10
# easi
# 100psm
# click
# soni
# hgsuite3422land
# 09058091854
# box385
# loyalti
# luck
# price
# maxå£7
# week
# presenc
# outgo
# romcapspam
# bluetooth
# london
# holiday
# kath
# forå£38
# tbspersolvo
# manchest
# jane
# onto
# tmobil
# forget
# 24hr
# cashbincouk
# wwwcashbincouk
# box334sk38ch
# callså£1minmobsmorelkpobox177hp51fl
# rude
# nasti
# 09064012103
# luci
# run
# valid
# comp
# ladi
# polic
# å£5000
# rcvd
# direct
# horo
# shortli
# slo4msg
# filthyguy
# invit
# rgd
# vatian
# rct
# thnq
# adrian
# btnationalr
# å£1000
# age16
# adp
# headset
# reward
# find
# trial
# champney
# posh
# chap
# prod
# would
# sport
# subscrib
# reveal
# textoper
# 89555
# tgxxrz
# httpwwwbubbletextcom
# term
# premium
# receiv
# toilet
# stolen
# cop
# sparkl
# wwwshortbreaksorguk
# 2025050
# 0121
# creat
# clair
# faster
# logo
# 8007
# sept
# visit
# partner
# idiot
# holder
# follow
# secret
# 2007
# tsc
# rate
# news
# xma
# winner
# draw
# auction
# ringtoneåá
# wmlid820554ad0a1705572711firsttrueåác
# excit
# å£200
# camera
# 4fil
# oper
# 80082
# afraid
# 87077
# ralli
# let
# notic
# poli
# unsubscrib
# attempt
# area
# summer
# 09096102316
# 150psm
# folk
# august
# fgkslpopw
# smsshsexnetun
# fgkslpo
# info
# entri
# orang
# becom
# uniqu
# arsen
# trebl
# dartboard
# landlin
# enter
# 02073162414
# 20pmin
# explicit
# join
# 30th
# wwwareyouuniquecouk
# await
# appli
# 80488
# connect
# fantasi
# dog
# ami
# guarante
# santa
# maniac
# slower
# wrote
# pic
# 150pmin
# brought
# pobox
# 62468
# choos
# sunshin
# ithi
# wwwasjesuscom
# freemsg
# dark
# xafter
# child
# 10pmin
# datingi
# coincid
# deliveri
# inform
# rreveal
# ufind
# specialcal
# link
# game
# 08707808226
# 1stchoicecouk
# enjoy
# free
# collect
# condit
# admir
# contact
# 08719181513
# 08719181503
# renew
# gender
# user
# quiz
# spree
# divorc
# weekli
# real
# thousand
# messag
# å£100
# teenag
# freephon
# ntwk
# 07008009200
# callså£1minmoremobsemspobox45po139wa
# latest
# video
# club
# 1000
# tonesrepli
# freemsgfav
# fanci
# å£250
# 0578
# cash
# commun
# award
# 01223585236
# nikiyu4net
# knicker
# date
# widelivecomindex
# httptm
# access
# tattoo
# 0800
# alert
# nokia
# call
# statement
# 10am7pm
# stop
# nearli
# immedi
# voucher
# cost
# sm
# å£12
# privat
# txt
# freeringtonerepli
# 85233
# gbpsm
# ban
# welcom
# chat
# 08714712388
# text
# ken
# barbi
# 2003
# adult
# 150pmsg
# 150p
# credit
# truli
# 86688
# _____Ham FEATURE______
# ltgt
# ill
# home
# work
# later
# said
# lor
#
# still
# ok
# come
# mail
# princess
# watch
# happen
# happi
# that
# go
# execut
# billion

# %%
len(lr.coef_[0])
# Out:
# 6729

# %% [markdown]
# These results make some sense as prize,claim,urgent,credit,sexi,rington are some features that we don't use s much in ur day to day messages but they do appear frequently in spams. Also we notice a lot of numbers in spam features.Maybe we can convert all numbers to a single string 'digit' next time and then apply the classifier. This might improve the accuracy a bit or atleast it'll reduce some dimensions. Punctuations can also be a good indicator for spam as one would expect a lot of exclamations and question marks in spams.
#
# Now that we understand the methodology for spam detection we'll try a shortcut for this approach i.e using scikit-learn's TfIdfvectorizer to perform all of above steps after preprocessing to lead to similar result.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tf=TfidfVectorizer()

# %%
X_train = tf.fit_transform(X['final_text'])
y_train = y
X_test1 = tf.transform(X_test['final_text'])
y_test1 = y_test

# %%
lr1 = LogisticRegression()
lr1.fit(X_train, y_train)
print("F1 SCORE", f1_score(y_test1,lr1.predict(X_test1)))
print("ACCURACY SCORE", lr1.score(X_test1,y_test1))
# Out:
# F1 SCORE 0.7913043478260869
# ACCURACY SCORE 0.95695067264574

# %%
confusion_matrix(y_train,lr1.predict(X_train))
# Out:
# array([[3833,    8],
#        [ 170,  446]], dtype=int64)

# %%
# Looking at some of the messages in X_test and their classification.
# We see that obivous spams are caught but some slip by e.g 22. It's difficult to detect such messages as it looks 
# like a normal conversation except at few words which completely changes the meaning.
# Maybe bi-grams will help as unigram doesn't capture the full meaning of the messages. Even then our solution
#works fine
for i in range(30):
    if lr.predict(X_test.iloc[i,6:])[0]==0:
        print(i,'     ',X_test.iloc[i,0],'---------','Not a spam')
    else:
        print(i,'     ',X_test.iloc[i,0],'---------','Spam!!!!!!')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-91-a4ab636115ae> in <module>()
#       5 #works fine
#       6 for i in range(30):
# ----> 7     if lr.predict(X_test.iloc[i,6:])[0]==0:
#       8         print(i,'     ',X_test.iloc[i,0],'---------','Not a spam')
#       9     else:
#
# c:\users\monika\appdata\local\programs\python\python36\lib\site-packages\sklearn\linear_model\base.py in predict(self, X)
#     322             Predicted class label per sample.
#     323         """
# --> 324         scores = self.decision_function(X)
#     325         if len(scores.shape) == 1:
#     326             indices = (scores > 0).astype(np.int)
#
# c:\users\monika\appdata\local\programs\python\python36\lib\site-packages\sklearn\linear_model\base.py in decision_function(self, X)
#     298                                  "yet" % {'name': type(self).__name__})
#     299
# --> 300         X = check_array(X, accept_sparse='csr')
#     301
#     302         n_features = self.coef_.shape[1]
#
# c:\users\monika\appdata\local\programs\python\python36\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     439                     "Reshape your data either using array.reshape(-1, 1) if "
#     440                     "your data has a single feature or array.reshape(1, -1) "
# --> 441                     "if it contains a single sample.".format(array))
#     442             array = np.atleast_2d(array)
#     443             # To ensure that array flags are maintained
#
# ValueError: Expected 2D array, got 1D array instead:
# array=[0. 0. 0. ... 0. 0. 0.].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.
